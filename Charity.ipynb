# %%
# Initial imports
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# #### What variable(s) are considered the target(s) for your model?
#
# ###### my (y) target variable will be " IS_SUCCESSFUL"
#
# #### What variable(s) are considered the feature(s) for your model?
#
# ###### my (x) features be everything else that isn't dropped.

# %%
# Data loading
file_path = Path("Resources/charity_data.csv")
df_charity = pd.read_csv(file_path)
df_charity
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# ...

# %% [markdown]
# ##### Drop EIN & Name

# %%
# Drop 'EIN' and 'NAME' columns
df_charity=df_charity.drop(columns=["EIN", "NAME"])
df_charity
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %% [markdown]
# ##### Determine the number of unique values for each column.

# %%
df_charity.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %% [markdown]
# ##### For those columns that have more than 10 unique values, determine the number of data points for each unique value.

# %%
df_charity["ASK_AMT"].value_counts()
# Out:
# 5000       25398
# 10478          3
# 15583          3
# 6725           3
# 63981          3
#            ...
# 772556         1
# 70103          1
# 27096          1
# 25049          1
# 1138700        1
# Name: ASK_AMT, Length: 8747, dtype: int64

# %%
charity = df_charity[df_charity["ASK_AMT"] == 5000] 
charity
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 2                   T5  CompanySponsored          C3000    ProductDev
# 5                   T3       Independent          C1200  Preservation
# 9                   T5  CompanySponsored          C3000    ProductDev
# 12                  T3  CompanySponsored          C1200  Preservation
# ...                ...               ...            ...           ...
# 34293               T3  CompanySponsored          C1000  Preservation
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
#
#       ORGANIZATION  STATUS INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# ...

# %%
charity["ORGANIZATION"].value_counts()
# Out:
# Trust           16189
# Association      8990
# Co-operative      193
# Corporation        26
# Name: ORGANIZATION, dtype: int64

# %%
charity["AFFILIATION"].value_counts()
# Out:
# CompanySponsored    13523
# Independent         11836
# Family/Parent          18
# National               12
# Regional                6
# Other                   3
# Name: AFFILIATION, dtype: int64

# %%
df_charity["ORGANIZATION"].value_counts()
# Out:
# Trust           23515
# Association     10255
# Co-operative      486
# Corporation        43
# Name: ORGANIZATION, dtype: int64

# %%
df_charity["AFFILIATION"].value_counts()
# Out:
# Independent         18480
# CompanySponsored    15705
# Family/Parent          64
# National               33
# Regional               13
# Other                   4
# Name: AFFILIATION, dtype: int64

# %%
df_charity[df_charity["ASK_AMT"] > 500000]
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 7                   T3       Independent          C2000  Preservation
# 17                  T3       Independent          C1000     Heathcare
# 40                  T3       Independent          C1000  Preservation
# 41                  T2       Independent          C1000    ProductDev
# 51                  T3       Independent          C1200  Preservation
# ...                ...               ...            ...           ...
# 34249               T3       Independent          C1000  Preservation
# 34250               T3       Independent          C1000     Heathcare
# 34252               T3       Independent          C1000  Preservation
# 34284               T3  CompanySponsored          C1000  Preservation
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
success = charity[charity["IS_SUCCESSFUL"] == 1]

# %%
success["INCOME_AMT"].value_counts()
# Out:
# 0                12523
# 1-9999             320
# 25000-99999        223
# 100000-499999      124
# 10000-24999        104
# 1M-5M                8
# 50M+                 1
# Name: INCOME_AMT, dtype: int64

# %%
success["SPECIAL_CONSIDERATIONS"].value_counts()
# Out:
# N    13291
# Y       12
# Name: SPECIAL_CONSIDERATIONS, dtype: int64

# %%
success["AFFILIATION"].value_counts()
# Out:
# Independent         8766
# CompanySponsored    4504
# Family/Parent         13
# National              11
# Regional               6
# Other                  3
# Name: AFFILIATION, dtype: int64

# %%
success["USE_CASE"].value_counts()
# Out:
# Preservation     11025
# ProductDev        2162
# CommunityServ      106
# Heathcare            9
# Other                1
# Name: USE_CASE, dtype: int64

# %%
df_charity["USE_CASE"].value_counts()
# Out:
# Preservation     28095
# ProductDev        5671
# CommunityServ      384
# Heathcare          146
# Other                3
# Name: USE_CASE, dtype: int64

# %%
charity["USE_CASE"].value_counts()
# Out:
# Preservation     20599
# ProductDev        4451
# CommunityServ      333
# Heathcare           14
# Other                1
# Name: USE_CASE, dtype: int64

# %%
df_charity["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4200        1
# C1245        1
# C1728        1
# C1236        1
# C4120        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
df_charity["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64
